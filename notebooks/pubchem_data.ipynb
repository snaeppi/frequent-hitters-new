# %%
import polars as pl

# %%
df = pl.read_parquet("../pubchem-bioassay/outputs/assay_rscores.parquet")
assay_metadata = pl.read_csv("../pubchem-bioassay/outputs/assay_metadata.csv")
df
# Out:
# shape: (229_440_312, 4)
# ┌──────────┬─────────────┬─────────────────────────────────┬───────────┐
# │ assay_id ┆ compound_id ┆ smiles                          ┆ r_score   │
# │ ---      ┆ ---         ┆ ---                             ┆ ---       │
# │ i32      ┆ i64         ┆ str                             ┆ f64       │
# ╞══════════╪═════════════╪═════════════════════════════════╪═══════════╡
# │ 155      ┆ 351034      ┆ CC1=CC(=C(C=C1CSC#N)CSC#N)C     ┆ 0.415071  │
# │ 155      ┆ 242131      ┆ CC(=O)O[C@H]1CC[C@]2([C@H](C1)… ┆ 0.570723  │
# │ 155      ┆ 252885      ┆ C1=NC(=C2C(=N1)SN=N2)N          ┆ 0.778259  │
# │ 155      ┆ 2519        ┆ CN1C=NC2=C1C(=O)N(C(=O)N2C)C    ┆ -0.103768 │
# │ 155      ┆ 3558        ┆ CC(C)(C(CCC(CBr)(C(=C)Cl)Cl)Br… ┆ 0.778259  │
# │ …        ┆ …           ┆ …                               ┆ …         │
# │ 2061326  ┆ 230290      ┆ CCN(CC)CCNC1=C2C(=C(C=C1)C)SC3… ┆ 4.565784  │
# ...
